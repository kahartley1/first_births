# %% [markdown]
# - create Yelp user account
# - create an [App](https://www.yelp.com/developers/v3/manage_app) - once created, Yelp will assign a `Client ID` and `API Key`
# - save your credentials somewhere safe
# - use the awesome article [here](https://towardsdatascience.com/getting-started-with-the-yelp-api-ac30915a77ae#906d) to guide you on using the [YelpAPI](https://github.com/gfairchild/yelpapi) package

# %%
from yelpapi import YelpAPI
import pandas as pd
import json

# %%
with open('keys.json') as fi:
    credentials = json.load(fi)

# %%
api_key = credentials['yelp_key']

# %%
client_id = credentials['yelp_id']

# %%
yelp_api = YelpAPI(api_key)
response = yelp_api.search_query(term = 'park', location = 'Nashville, TN', search_limit = 300)

# %%
response
# Out:
# {'businesses': [{'id': 'zzXDi0Pdv0s84M-oQaIa_g',
#    'alias': 'radnor-lake-state-park-nashville',
#    'name': 'Radnor Lake State Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x_k73AlKQx0-cjGwXKtuHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radnor-lake-state-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 208,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.062764, 'longitude': -86.809891},
#    'transactions': [],
#    'location': {'address1': '1160 Otter Creek Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37220',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1160 Otter Creek Rd', 'Nashville, TN 37220']},
#    'phone': '+16153733467',
#    'display_phone': '(615) 373-3467',
#    'distance': 8886.359114102528},
#   {'id': 'WjWDl782jABdLzUu9nof3g',
#    'alias': 'shelby-park-nashville',
#    'name': 'Shelby Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hJoCFPJbOHMB3doOgczNgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shelby-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 56,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'playgrounds', 'title': 'Playgrounds'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.173435340130204,
#     'longitude': -86.73402597753878},
#    'transactions': [],
#    'location': {'address1': '2021 Fatherland St',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37206',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2021 Fatherland St', 'Nashville, TN 37206']},
#    'phone': '+16158628474',
#    'display_phone': '(615) 862-8474',
#    'distance': 5446.4905068175785},
#   {'id': 'CRmZDx9rW3HFo0Z9FbfyEw',
#    'alias': 'cumberland-park-nashville',
#    'name': 'Cumberland Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xRQAmw-GZf4FDgB6ONnjOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cumberland-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 32,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'playgrounds', 'title': 'Playgrounds'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1626862381255,
#     'longitude': -86.7707061767578},
#    'transactions': [],
#    'location': {'address1': '592 S 1st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37206',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['592 S 1st St', 'Nashville, TN 37206']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2811.8380691921807},
#   {'id': '73esU0u3hYIPPqCScAA2HQ',
#    'alias': 'centennial-park-nashville',
#    'name': 'Centennial Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yiE3ALsktOW9-7xLgZtkKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/centennial-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 219,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.149064, 'longitude': -86.811993},
#    'transactions': [],
#    'location': {'address1': '2500 W End Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2500 W End Ave', 'Nashville, TN 37203']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3511.073611710252},
#   {'id': 'Wjv13Wi_9RPRJPg-uMkcRQ',
#    'alias': 'bicentennial-capitol-mall-state-park-nashville-2',
#    'name': 'Bicentennial Capitol Mall State Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I5sZVJd_nfyeSNIAWvdxYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bicentennial-capitol-mall-state-park-nashville-2?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 86,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'walkingtours', 'title': 'Walking Tours'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1680549, 'longitude': -86.7863334},
#    'transactions': [],
#    'location': {'address1': '600 James Robertson Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37243',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['600 James Robertson Pkwy', 'Nashville, TN 37243']},
#    'phone': '+16157415280',
#    'display_phone': '(615) 741-5280',
#    'distance': 3512.519020979029},
#   {'id': 'yu9e-_S7U97kleJQw0eOzQ',
#    'alias': 'richland-creek-greenway-nashville',
#    'name': 'Richland Creek Greenway',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fiqTzBlXoveCuxTQTNf0lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/richland-creek-greenway-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 30,
#    'categories': [{'alias': 'hiking', 'title': 'Hiking'},
#     {'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.140481933298005,
#     'longitude': -86.84318291384135},
#    'transactions': [],
#    'location': {'address1': '4601 Murphy Rd',
#     'address2': '',
#     'address3': 'McCabe Trailhead',
#     'city': 'Nashville',
#     'zip_code': '37246',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['4601 Murphy Rd',
#      'McCabe Trailhead',
#      'Nashville, TN 37246']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6084.633101853098},
#   {'id': 'DiG2uoaL8ZLQcpGlkHraag',
#    'alias': 'long-hunter-state-park-hermitage',
#    'name': 'Long Hunter State Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KLoy5sV_unWU5RNz7Xi3Qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/long-hunter-state-park-hermitage?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 38,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'hiking', 'title': 'Hiking'},
#     {'alias': 'campgrounds', 'title': 'Campgrounds'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.0943884, 'longitude': -86.5571708},
#    'transactions': [],
#    'location': {'address1': '2910 Hobson Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Hermitage',
#     'zip_code': '37076',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2910 Hobson Pike', 'Hermitage, TN 37076']},
#    'phone': '+16158852422',
#    'display_phone': '(615) 885-2422',
#    'distance': 20157.552178797643},
#   {'id': 'eQB8iaJ5utCWnm4P2qUcCw',
#    'alias': 'percy-priest-lake-nashville',
#    'name': 'Percy Priest Lake',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/abQBy2mu0LqAsIQ76HwM3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/percy-priest-lake-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 14,
#    'categories': [{'alias': 'lakes', 'title': 'Lakes'},
#     {'alias': 'boating', 'title': 'Boating'},
#     {'alias': 'fishing', 'title': 'Fishing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.156946, 'longitude': -86.6175},
#    'transactions': [],
#    'location': {'address1': '3737 Bell Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37214',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['3737 Bell Rd', 'Nashville, TN 37214']},
#    'phone': '+16158891975',
#    'display_phone': '(615) 889-1975',
#    'distance': 14348.497418769895},
#   {'id': '356dzXl7YXrWq6MrvSz23Q',
#    'alias': 'sevier-park-nashville',
#    'name': 'Sevier Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/86ryaHDHr8oEgTvkoRkSGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sevier-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 39,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'playgrounds', 'title': 'Playgrounds'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1195273, 'longitude': -86.7907212},
#    'transactions': [],
#    'location': {'address1': '3000 Granny White Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37204',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['3000 Granny White Pike', 'Nashville, TN 37204']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2381.754220095538},
#   {'id': 'GoLUrmNHkh1x__YUUr21RQ',
#    'alias': 'two-rivers-park-nashville',
#    'name': 'Two Rivers Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YMMGc5AeVC-_NzpCT951Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-rivers-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 15,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'golf', 'title': 'Golf'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.185593, 'longitude': -86.678432},
#    'transactions': [],
#    'location': {'address1': '3150 Mcgavock Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37214',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['3150 Mcgavock Pike', 'Nashville, TN 37214']},
#    'phone': '+16158837781',
#    'display_phone': '(615) 883-7781',
#    'distance': 10213.65601928462},
#   {'id': 'ltpXQoweOGQDlIO3soD3XA',
#    'alias': 'love-circle-nashville',
#    'name': 'Love Circle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P7N0zfZDQ48hTaCSjYmOtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/love-circle-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 28,
#    'categories': [{'alias': 'hiking', 'title': 'Hiking'},
#     {'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.137188, 'longitude': -86.815874},
#    'transactions': [],
#    'location': {'address1': 'Love Cir',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37212',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['Love Cir', 'Nashville, TN 37212']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3668.1083548051397},
#   {'id': '2-qIaZy7A6WWXSPfyX60eA',
#    'alias': 'percy-warner-park-nashville',
#    'name': 'Percy Warner Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vMo9p2hzVB3NR5JrRD-ycg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/percy-warner-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 115,
#    'categories': [{'alias': 'hiking', 'title': 'Hiking'},
#     {'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.055337, 'longitude': -86.890643},
#    'transactions': [],
#    'location': {'address1': '2500 Old Hickory Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37221',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2500 Old Hickory Blvd', 'Nashville, TN 37221']},
#    'phone': '+16158628415',
#    'display_phone': '(615) 862-8415',
#    'distance': 13815.766359297815},
#   {'id': 'OyYYSxyBHkfSjEdif_Ty0Q',
#    'alias': 'reservoir-park-nashville',
#    'name': 'Reservoir Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ox-ZncXdKWilhJMSdi2bBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reservoir-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 4,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1368669944961,
#     'longitude': -86.7788793913909},
#    'transactions': [],
#    'location': {'address1': '1701 8th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1701 8th Ave S', 'Nashville, TN 37203']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 309.800048305762},
#   {'id': 'JDEKR-qd3Wo3fgZWyqPUgQ',
#    'alias': 'fannie-mae-dees-park-nashville',
#    'name': 'Fannie Mae Dees Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n79bY1heiTp3YBvf-CpXPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fannie-mae-dees-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 38,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'playgrounds', 'title': 'Playgrounds'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.13861, 'longitude': -86.80604},
#    'transactions': [],
#    'location': {'address1': '2400 Blakemore Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37212',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2400 Blakemore Ave', 'Nashville, TN 37212']},
#    'phone': '+16158628400',
#    'display_phone': '(615) 862-8400',
#    'distance': 2738.2228859064485},
#   {'id': 'e3YMcMeIAg0zzEF2-hbPYQ',
#    'alias': 'harpeth-river-state-park-kingston-springs-2',
#    'name': 'Harpeth River State Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D_Ctr0TEPOQME6AE-_LSVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harpeth-river-state-park-kingston-springs-2?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 16,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'hiking', 'title': 'Hiking'},
#     {'alias': 'fishing', 'title': 'Fishing'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.15071045450449,
#     'longitude': -87.11617411765306},
#    'transactions': [],
#    'location': {'address1': '1640 Cedar Hill Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Kingston Springs',
#     'zip_code': '37082',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1640 Cedar Hill Rd', 'Kingston Springs, TN 37082']},
#    'phone': '+16159522099',
#    'display_phone': '(615) 952-2099',
#    'distance': 30623.434574293104},
#   {'id': 'cS7f6dX8C-r4P5vsbh-HPA',
#    'alias': 'shelby-bottoms-nature-center-nashville',
#    'name': 'Shelby Bottoms Nature Center',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hB1b3G768xr6McqoqWlpxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shelby-bottoms-nature-center-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 21,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'kids_activities', 'title': 'Kids Activities'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1650348, 'longitude': -86.7335491},
#    'transactions': [],
#    'location': {'address1': '1900 Davidson St',
#     'address2': None,
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37206',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1900 Davidson St', 'Nashville, TN 37206']},
#    'phone': '+16158628539',
#    'display_phone': '(615) 862-8539',
#    'distance': 4841.0049176435905},
#   {'id': 'z2FRDJSxRR3mmC9syR25xA',
#    'alias': 'the-parthenon-nashville',
#    'name': 'The Parthenon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/juyVpfGYbyfqXlwhrXA7GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-parthenon-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 475,
#    'categories': [{'alias': 'landmarks',
#      'title': 'Landmarks & Historical Buildings'},
#     {'alias': 'artmuseums', 'title': 'Art Museums'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.14967469964605,
#     'longitude': -86.81334871296693},
#    'transactions': [],
#    'location': {'address1': '2500 West End Ave',
#     'address2': '',
#     'address3': 'Centennial Park',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2500 West End Ave',
#      'Centennial Park',
#      'Nashville, TN 37203']},
#    'phone': '+16158628431',
#    'display_phone': '(615) 862-8431',
#    'distance': 3649.132531857572},
#   {'id': 'tKxXZd00zZ24jDmJJcUYPQ',
#    'alias': 'natchez-trace-parkway-nashville',
#    'name': 'Natchez Trace Parkway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w_wrVyLHeb4nW9oHE29jkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/natchez-trace-parkway-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 40,
#    'categories': [{'alias': 'landmarks',
#      'title': 'Landmarks & Historical Buildings'},
#     {'alias': 'parks', 'title': 'Parks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 36.0322963844933,
#     'longitude': -86.9762194022369},
#    'transactions': [],
#    'location': {'address1': 'Starting At Tn Highway 100',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37246',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['Starting At Tn Highway 100', 'Nashville, TN 37246']},
#    'phone': '+18003057417',
#    'display_phone': '(800) 305-7417',
#    'distance': 21509.332124410947},
#   {'id': 'Ll0Wbo9UZtAhNK6W_u13Nw',
#    'alias': 'red-caboose-park-nashville',
#    'name': 'Red Caboose Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WwZsU61v_dwUAf7KBC8-nA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-caboose-park-nashville?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 4,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.0737724, 'longitude': -86.9352188},
#    'transactions': [],
#    'location': {'address1': '694-698 Colice Jeanne Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37221',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['694-698 Colice Jeanne Rd', 'Nashville, TN 37221']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 16018.074269198496},
#   {'id': 'nRbgiD7uTBqfV_yS8uVfAw',
#    'alias': 'seven-points-recreation-area-hermitage',
#    'name': 'Seven Points Recreation Area',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zlVu0v_GWUu3GaNJ3_7FYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seven-points-recreation-area-hermitage?adjust_creative=MQNwvLri_UXL3Jrl-lPNmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MQNwvLri_UXL3Jrl-lPNmg',
#    'review_count': 9,
#    'categories': [{'alias': 'boating', 'title': 'Boating'},
#     {'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'campgrounds', 'title': 'Campgrounds'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1338654, 'longitude': -86.5704803},
#    'transactions': [],
#    'location': {'address1': '1810 Stewarts Ferry Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Hermitage',
#     'zip_code': '37076',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1810 Stewarts Ferry Pike', 'Hermitage, TN 37076']},
#    'phone': '+16158895198',
#    'display_phone': '(615) 889-5198',
#    'distance': 18363.98798384078}],
#  'total': 241,
#  'region': {'center': {'longitude': -86.7755126953125,
#    'latitude': 36.137698356986476}}}
